# %% [markdown]
# <a href="https://colab.research.google.com/github/teguhmuflih/AWS-SR-TA/blob/main/Analisis_Pada_Pengujian_Alat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cf_laki_5cm = np.array([[17, 8], [2, 23]])
print(cf_laki_5cm)
# Out:
# [[17  8]
#  [ 2 23]]

# %%
cf_pr_5cm = np.array([[19, 6], [0, 25]])
print(cf_pr_5cm)
# Out:
# [[19  6]
#  [ 0 25]]

# %%
cf_laki_10cm = np.array([[5, 20], [0, 25]])
print(cf_laki_10cm)
# Out:
# [[ 5 20]
#  [ 0 25]]

# %%
cf_pr_10cm = np.array([[9, 16], [1, 24]])
print(cf_pr_10cm)
# Out:
# [[ 9 16]
#  [ 1 24]]

# %%
cf_laki_15cm = np.array([[8, 17 ], [2, 23]])
print(cf_laki_15cm)
# Out:
# [[ 8 17]
#  [ 2 23]]

# %%
cf_pr_15cm = np.array([[8, 17], [1, 24]])
print(cf_pr_15cm)
# Out:
# [[ 8 17]
#  [ 1 24]]

# %%
def metric(matrix):
  accuracy =(matrix[0][0]+matrix[1][1])/(matrix[0][0]+matrix[1][0]+matrix[0][1]+matrix[1][1])
  precision = matrix[0][0]/(matrix[0][0]+matrix[0][1])
  recall = matrix[0][0]/(matrix[0][0]+matrix[1][0])
  f1 = 2*precision*recall/(precision+recall)
  print(f"Accuracy = {accuracy:.2f}")
  print(f"Precision = {precision:.2f}")
  print(f"Recall = { recall:.2f} ")
  print(f"F-1 Score = {f1:.2f}")
  return precision, recall, f1

# %%
def confussion_matrix(value):
  plt.figure(dpi=600)
  sns.heatmap(value, xticklabels=["Buka","Tutup"], yticklabels=["Buka","Tutup"], 
              annot=True, fmt='g')
  plt.xlabel('Actual', fontsize=15)
  plt.ylabel('Predicted',fontsize=15)
  plt.show()

# %% [markdown]
# # heatmap Confussion Matrix dan nilai

# %%
confussion_matrix(cf_laki_5cm)

# %%
metric(cf_laki_5cm)
# Out:
# Accuracy = 0.80
# Precision = 0.68
# Recall = 0.89
# F-1 Score = 0.77
# (0.68, 0.8947368421052632, 0.7727272727272727)

# %%
confussion_matrix(cf_laki_10cm)

# %%
metric(cf_laki_10cm)
# Out:
# Accuracy = 0.60
# Precision = 0.20
# Recall = 1.00
# F-1 Score = 0.33
# (0.2, 1.0, 0.33333333333333337)

# %%
confussion_matrix(cf_laki_15cm)

# %%
metric(cf_laki_15cm)
# Out:
# Accuracy = 0.62
# Precision = 0.32
# Recall = 0.80
# F-1 Score = 0.46
# (0.32, 0.8, 0.45714285714285713)

# %%
confussion_matrix(cf_pr_5cm)

# %%
metric(cf_pr_5cm)
# Out:
# Accuracy = 0.88
# Precision = 0.76
# Recall = 1.00
# F-1 Score = 0.86
# (0.76, 1.0, 0.8636363636363636)

# %%
confussion_matrix(cf_pr_10cm)

# %%
metric(cf_pr_10cm)
# Out:
# Accuracy = 0.66
# Precision = 0.36
# Recall = 0.90
# F-1 Score = 0.51
# (0.36, 0.9, 0.5142857142857143)

# %%
confussion_matrix(cf_pr_15cm)

# %%
metric(cf_pr_15cm)
# Out:
# Accuracy = 0.64
# Precision = 0.32
# Recall = 0.89
# F-1 Score = 0.47
# (0.32, 0.8888888888888888, 0.47058823529411764)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
#memperlihatkan nilai diatas barplot
def show_values(axs, orient="v", space=.01):
    def _single(ax):
        if orient == "v":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() / 2
                _y = p.get_y() + p.get_height() + (p.get_height()*0.01)
                value = '{:.1f}'.format(p.get_height())
                ax.text(_x, _y, value, ha="center") 
        elif orient == "h":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() + float(space)
                _y = p.get_y() + p.get_height() - (p.get_height()*0.5)
                value = '{:.1f}'.format(p.get_width())
                ax.text(_x, _y, value, ha="left")

    if isinstance(axs, np.ndarray):
        for idx, ax in np.ndenumerate(axs):
            _single(ax)
    else:
        _single(axs)

# %%
data_path = "/content/drive/MyDrive/Dataset_TA/Data Accuracy/Pengujian Deployment.xlsx"
lima = pd.read_excel(data_path, sheet_name="5 cm")
sepuluh = pd.read_excel(data_path, sheet_name="10 cm")
limabelas = pd.read_excel(data_path, sheet_name="15 cm")

# %%
plt.figure(figsize=(12,8))
bar_lima=sns.barplot(y="Akurasi", x="Jenis Kelamin", data=lima)
plt.title("Akurasi pada jarak 5 cm", fontsize=20)
plt.ylabel ("Akurasi (%)")
plt.rcParams['figure.dpi'] = 300
plt.ylim(1,110)
show_values(bar_lima)

# %%
plt.figure(figsize=(12,8))
bar_sepuluh=sns.barplot(y="Akurasi", x="Jenis Kelamin", data=sepuluh)
plt.title("Akurasi pada jarak 10 cm", fontsize=20)
plt.ylabel ("Akurasi (%)")
plt.rcParams['figure.dpi'] = 300
show_values(bar_sepuluh)

# %%
plt.figure(figsize=(12,8))
bar_limabelas=sns.barplot(y="Akurasi", x="Jenis Kelamin", data=limabelas)
plt.title("Akurasi pada jarak 15 cm", fontsize=20)
plt.ylabel ("Akurasi (%)")
plt.rcParams['figure.dpi'] = 300
show_values(bar_limabelas)
